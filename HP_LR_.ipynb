# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pylab
import scipy.stats as stats

# %%
df= pd.read_csv('/content/Holiday_Package (1).csv')
df.head(1)
# Out:
#    Unnamed: 0 Holliday_Package  Salary  age  educ  no_young_children  \
# 0           1               no   48412   30     8                  1
#
#    no_older_children foreign
# 0                  1      no

# %%
df.tail(1)
# Out:
#      Unnamed: 0 Holliday_Package  Salary  age  educ  no_young_children  \
# 871         872               no   74659   51    10                  0
#
#      no_older_children foreign
# 871                  0     yes

# %%
df.shape
# Out:
# (872, 8)

# %%
df= df.drop('Unnamed: 0', axis=1)
df.head(1)
# Out:
#   Holliday_Package  Salary  age  educ  no_young_children  no_older_children  \
# 0               no   48412   30     8                  1                  1
#
#   foreign
# 0      no

# %%
df.rename(columns={'Holliday_Package': 'Holiday_Package'}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Holiday_Package    872 non-null    object
#  1   Salary             872 non-null    int64
#  2   age                872 non-null    int64
#  3   educ               872 non-null    int64
#  4   no_young_children  872 non-null    int64
#  5   no_older_children  872 non-null    int64
#  6   foreign            872 non-null    object
# dtypes: int64(5), object(2)
# memory usage: 47.8+ KB

# %%
df.isnull().sum()
# Out:
# Holiday_Package      0
# Salary               0
# age                  0
# educ                 0
# no_young_children    0
# no_older_children    0
# foreign              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               Salary         age        educ  no_young_children  \
# count     872.000000  872.000000  872.000000         872.000000
# mean    47729.172018   39.955275    9.307339           0.311927
# std     23418.668531   10.551675    3.036259           0.612870
# min      1322.000000   20.000000    1.000000           0.000000
# 25%     35324.000000   32.000000    8.000000           0.000000
# 50%     41903.500000   39.000000    9.000000           0.000000
# 75%     53469.500000   48.000000   12.000000           0.000000
# max    236961.000000   62.000000   21.000000           3.000000
#
#        no_older_children
# count         872.000000
# mean            0.982798
# std             1.086786
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             2.000000
# max             6.000000

# %%
df.skew(axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Salary               3.103216
# age                  0.146412
# educ                -0.045501
# no_young_children    1.946515
# no_older_children    0.953951
# dtype: float64

# %%
df.describe(include='object')
# Out:
#        Holiday_Package foreign
# count              872     872
# unique               2       2
# top                 no      no
# freq               471     656

# %%
for i in df:
  if df[i].dtype=='int64': 
   plt.figure
   ax=sns.boxplot(x=df[i])
   plt.show()

# %%
for i in df:
  if df[i].dtype=='int64': 
   plt.figure
   ax=sns.distplot(df[i], kde= True);
   plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for i in df:
  if df[i].dtype=='int64': 
   print("Description of" +  i)
   print('..................')
   print(df[i].describe())
# Out:
# Description ofSalary
# ..................
# count       872.000000
# mean      47729.172018
# std       23418.668531
# min        1322.000000
# 25%       35324.000000
# 50%       41903.500000
# 75%       53469.500000
# max      236961.000000
# Name: Salary, dtype: float64
# Description ofage
# ..................
# count    872.000000
# mean      39.955275
# std       10.551675
# min       20.000000
# 25%       32.000000
# 50%       39.000000
# 75%       48.000000
# max       62.000000
# Name: age, dtype: float64
# Description ofeduc
# ..................
# count    872.000000
# mean       9.307339
# std        3.036259
# min        1.000000
# 25%        8.000000
# 50%        9.000000
# 75%       12.000000
# max       21.000000
# Name: educ, dtype: float64
# Description ofno_young_children
# ..................
# count    872.000000
# mean       0.311927
# std        0.612870
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000
# ...

# %%
for i in df:
  if df[i].dtype=='int64': 
    print("Unique Values of" +  i)
    print('..................')
    print(df[i].nunique())
# Out:
# Unique Values ofSalary
# ..................
# 864
# Unique Values ofage
# ..................
# 43
# Unique Values ofeduc
# ..................
# 20
# Unique Values ofno_young_children
# ..................
# 4
# Unique Values ofno_older_children
# ..................
# 7

# %%
#Since the number of unique values are only 4 and 7 in 'no_young_children' and 
#'no_older_children'.
# Hence analysing them with the categorical variables can give good insights.

# %%
df.columns
# Out:
# Index(['Holiday_Package', 'Salary', 'age', 'educ', 'no_young_children',
#        'no_older_children', 'foreign'],
#       dtype='object')

# %%
catcol= ['Holiday_Package', 'no_young_children',
       'no_older_children', 'foreign']
catcol
# Out:
# ['Holiday_Package', 'no_young_children', 'no_older_children', 'foreign']

# %%
def univarcatcol(column,nbins):
    print("Percentage Value counts of " + column)
    print("------------------------")
    print(df[column].value_counts(normalize = True),end=' ')
    print('')
    print('')
       
    
    plt.figure()
    print("Frequency Distribution of " + column)
    print("------------------------")
    ax = sns.countplot(y=df[column])
    plt.show()

# %%
for x in catcol:
    univarcatcol(x,20)
# Out:
# Percentage Value counts of Holiday_Package
# ------------------------
# no     0.540138
# yes    0.459862
# Name: Holiday_Package, dtype: float64
#
# Frequency Distribution of Holiday_Package
# ------------------------
# Percentage Value counts of no_young_children
# ------------------------
# 0    0.762615
# 1    0.168578
# 2    0.063073
# 3    0.005734
# Name: no_young_children, dtype: float64
#
# Frequency Distribution of no_young_children
# ------------------------
# Percentage Value counts of no_older_children
# ------------------------
# 0    0.450688
# 2    0.238532
# 1    0.227064
# 3    0.063073
# 4    0.016055
# 5    0.002294
# 6    0.002294
# Name: no_older_children, dtype: float64
#
# Frequency Distribution of no_older_children
# ------------------------
# Percentage Value counts of foreign
# ------------------------
# no     0.752294
# yes    0.247706
# Name: foreign, dtype: float64
#
# Frequency Distribution of foreign
# ------------------------

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(7,5))
sns.heatmap(df.corr(),cmap="YlGnBu", annot=True,fmt=".2f")

# %%
sns.scatterplot(x= 'age', y='no_young_children', data=df)

# %%
df.columns
# Out:
# Index(['Holiday_Package', 'Salary', 'age', 'educ', 'no_young_children',
#        'no_older_children', 'foreign'],
#       dtype='object')

# %%
sns.countplot(x='Holiday_Package', hue='foreign',data=df)
pd.crosstab(df['Holiday_Package'], df['foreign'], margins=True)
# Out:
# foreign           no  yes  All
# Holiday_Package
# no               402   69  471
# yes              254  147  401
# All              656  216  872

# %%
sns.countplot(x='Holiday_Package', hue='no_young_children', data=df)
pd.crosstab(df['Holiday_Package'], df['no_young_children'], margins=True)
# Out:
# no_young_children    0    1   2  3  All
# Holiday_Package
# no                 326  100  42  3  471
# yes                339   47  13  2  401
# All                665  147  55  5  872

# %%
sns.countplot(x='Holiday_Package', hue='no_older_children', data=df)
pd.crosstab(df['Holiday_Package'], df['no_older_children'], margins=True)
# Out:
# no_older_children    0    1    2   3   4  5  6  All
# Holiday_Package
# no                 231  102  102  27   7  2  0  471
# yes                162   96  106  28   7  0  2  401
# All                393  198  208  55  14  2  2  872

# %%
sns.countplot(x='foreign', hue='no_young_children', data=df)
pd.crosstab(df['foreign'], df['no_young_children'], margins=True)
# Out:
# no_young_children    0    1   2  3  All
# foreign
# no                 513  103  38  2  656
# yes                152   44  17  3  216
# All                665  147  55  5  872

# %%
sns.countplot(x='foreign', hue='no_older_children', data=df)
pd.crosstab(df['foreign'], df['no_older_children'], margins=True)
# Out:
# no_older_children    0    1    2   3   4  5  6  All
# foreign
# no                 316  127  153  43  13  2  2  656
# yes                 77   71   55  12   1  0  0  216
# All                393  198  208  55  14  2  2  872

# %%
catcol
# Out:
# ['Holiday_Package', 'no_young_children', 'no_older_children', 'foreign']

# %%
def bivarnumcat(column,nbins):
    print("Mean of age for " + column)
    print(df.groupby(df[column])['age'].mean(), end=' ')
    print('')
    print('')
       
    
    plt.figure()
    print("Plot of age vs " + column)
    print("----------------------------------------------------------------------------")
    ax = sns.boxplot(x= df[column], y='age', data=df)
    plt.show()

# %%
for x in catcol:
    bivarnumcat(x,20)
# Out:
# Mean of age for Holiday_Package
# Holiday_Package
# no     40.853503
# yes    38.900249
# Name: age, dtype: float64
#
# Plot of age vs Holiday_Package
# ----------------------------------------------------------------------------
# Mean of age for no_young_children
# no_young_children
# 0    43.296241
# 1    29.265306
# 2    29.072727
# 3    29.600000
# Name: age, dtype: float64
#
# Plot of age vs no_young_children
# ----------------------------------------------------------------------------
# Mean of age for no_older_children
# no_older_children
# 0    41.615776
# 1    39.161616
# 2    37.798077
# 3    38.800000
# 4    40.285714
# 5    43.500000
# 6    42.500000
# Name: age, dtype: float64
#
# Plot of age vs no_older_children
# ----------------------------------------------------------------------------
# Mean of age for foreign
# foreign
# no     40.603659
# yes    37.986111
# Name: age, dtype: float64
#
# Plot of age vs foreign
# ...

# %%
def bivarnumcat(column,nbins):
    print("Mean of Salary for " + column)
    print(df.groupby(df[column])['Salary'].mean(), end=' ')
    print('')
    print('')
       
    
    plt.figure()
    print("Plot of Salry vs " + column)
    print("----------------------------------")
    ax = sns.boxplot(x= df[column], y='Salary', data=df)
    plt.show()

# %%
for x in catcol:
    bivarnumcat(x,20)
# Out:
# Mean of Salary for Holiday_Package
# Holiday_Package
# no     51739.443737
# yes    43018.852868
# Name: Salary, dtype: float64
#
# Plot of Salry vs Holiday_Package
# ----------------------------------
# Mean of Salary for no_young_children
# no_young_children
# 0    48210.348872
# 1    45810.176871
# 2    47275.854545
# 3    45137.600000
# Name: Salary, dtype: float64
#
# Plot of Salry vs no_young_children
# ----------------------------------
# Mean of Salary for no_older_children
# no_older_children
# 0    45520.888041
# 1    46920.363636
# 2    50788.350962
# 3    50339.581818
# 4    65118.714286
# 5    59185.500000
# 6    38605.000000
# Name: Salary, dtype: float64
#
# Plot of Salry vs no_older_children
# ----------------------------------
# Mean of Salary for foreign
# foreign
# no     50429.248476
# yes    39528.939815
# Name: Salary, dtype: float64
#
# Plot of Salry vs foreign
# ----------------------------------

# %%
def bivarnumcat(column,nbins):
    print("Mean of educ for " + column)
    print(df.groupby(df[column])['educ'].mean(), end=' ')
    print('')
    print('')
       
    
    plt.figure()
    print("Plot of educ vs " + column)
    print("----------------------------------")
    ax = sns.boxplot(x= df[column], y='educ', data=df)
    plt.show()

# %%
for x in catcol:
    bivarnumcat(x,20)
# Out:
# Mean of educ for Holiday_Package
# Holiday_Package
# no     9.594480
# yes    8.970075
# Name: educ, dtype: float64
#
# Plot of educ vs Holiday_Package
# ----------------------------------
# Mean of educ for no_young_children
# no_young_children
# 0     9.144361
# 1     9.761905
# 2     9.890909
# 3    11.200000
# Name: educ, dtype: float64
#
# Plot of educ vs no_young_children
# ----------------------------------
# Mean of educ for no_older_children
# no_older_children
# 0     9.544529
# 1     8.792929
# 2     9.461538
# 3     8.709091
# 4    10.285714
# 5     8.000000
# 6     8.500000
# Name: educ, dtype: float64
#
# Plot of educ vs no_older_children
# ----------------------------------
# Mean of educ for foreign
# foreign
# no     10.038110
# yes     7.087963
# Name: educ, dtype: float64
#
# Plot of educ vs foreign
# ----------------------------------

# %%
fig = plt.subplots(figsize=(12,8))
sns.boxplot(x='Holiday_Package', y='Salary', hue='foreign',data=df)

# %%
df.columns
# Out:
# Index(['Holiday_Package', 'Salary', 'age', 'educ', 'no_young_children',
#        'no_older_children', 'foreign'],
#       dtype='object')

# %%
fig = plt.subplots(figsize=(12,8))
sns.boxplot(x='Holiday_Package', y='Salary', hue='no_young_children',data=df)

# %%
fig = plt.subplots(figsize=(12,8))
sns.boxplot(x='Holiday_Package', y='Salary', hue='no_older_children',data=df)

# %%
fig = plt.subplots(figsize=(12,8))
sns.boxplot(x='Holiday_Package', y='age', hue='foreign',data=df)

# %%
fig = plt.subplots(figsize=(12,8))
sns.boxplot(x='Holiday_Package', y='age', hue='no_young_children',data=df)

# %%
fig = plt.subplots(figsize=(12,8))
sns.boxplot(x='Holiday_Package', y='age', hue='no_older_children',data=df)

# %%
fig = plt.subplots(figsize=(12,8))
sns.boxplot(x='Holiday_Package', y='educ', hue='foreign',data=df)

# %%
fig = plt.subplots(figsize=(12,8))
sns.boxplot(x='Holiday_Package', y='educ', hue='no_young_children',data=df)

# %%
fig = plt.subplots(figsize=(12,8))
sns.boxplot(x='Holiday_Package', y='educ', hue='no_older_children',data=df)

# %%
# Outlier detection

# %%
numcol= ['Salary','age','educ']

# %%
Lower_outlier = []
Upper_outlier = []
for i in range(0,3):
    Q1 = df[numcol[i]].quantile(0.25)
    Q3 = df[numcol[i]].quantile(0.75)
    IQR = Q3 - Q1
    Lower_outlier.append(df[df[numcol[i]] < (Q1 - 1.5*IQR)].count()[0])
    Upper_outlier.append(df[df[numcol[i]] > (Q3 + 1.5*IQR)].count()[0])

outliers = pd.DataFrame(data = Lower_outlier, columns =['Lower Outliers Count'], index = numcol)
outliers['Lower Outliers Percentage'] =  round(outliers['Lower Outliers Count'].apply(lambda x: x*100/len(df)),2)
outliers['Upper Outliers Count'] = Upper_outlier
outliers['Upper outliers Percentage'] = round(outliers['Upper Outliers Count'].apply(lambda x: x*100/len(df)),2)
outliers['Total Outliers Count'] = outliers['Lower Outliers Count'] + outliers['Upper Outliers Count']
outliers['Total Outliers Percentage'] = round(outliers['Total Outliers Count'].apply(lambda x: x*100/len(df)),2)
outliers
# Out:
#         Lower Outliers Count  Lower Outliers Percentage  Upper Outliers Count  \
# Salary                     1                       0.11                    56
# age                        0                       0.00                     0
# educ                       1                       0.11                     3
#
#         Upper outliers Percentage  Total Outliers Count  \
# Salary                       6.42                    57
# age                          0.00                     0
# educ                         0.34                     4
#
#         Total Outliers Percentage
# Salary                       6.54
# age                          0.00
# educ                         0.46

# %%
# MODEL 1- Without Outliers treatment

# %%
df1= df.copy()

# %%
df1.head(1)
# Out:
#   Holiday_Package  Salary  age  educ  no_young_children  no_older_children  \
# 0              no   48412   30     8                  1                  1
#
#   foreign
# 0      no

# %%
for i in df1.columns:
    if df1[i].dtype == 'O':
        df1[i] = pd.Categorical(df1[i]).codes

# %%
df1.dtypes
# Out:
# Holiday_Package       int8
# Salary               int64
# age                  int64
# educ                 int64
# no_young_children    int64
# no_older_children    int64
# foreign               int8
# dtype: object

# %%
df1.shape
# Out:
# (872, 7)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df1.drop('Holiday_Package', axis=1)
y = df1[['Holiday_Package']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %%
print('X_train',X_train.shape)
print('X_test',X_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
print('Total observations is', X_train.shape[0]+X_test.shape[0])
# Out:
# X_train (610, 6)
# X_test (262, 6)
# y_train (610, 1)
# y_test (262, 1)
# Total observations is 872

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# Tuning
from sklearn.model_selection import GridSearchCV

# Evaulation Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

# %%
Log_Reg = LogisticRegression(random_state = 1)

# %%
# Combination 1
#penalty: 'l2'
#solver: 'newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'

# %%
param_grid = {'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'penalty': ['l2'],
    'max_iter': [ 1000, 5000, 10000 ], 
     'C': [0.001,.009,0.01,.09,1,5,10,25],
     'class_weight': [{1: 0.5, 0: 0.5},{1:0.55, 0:0.45}]
    }

# %%
grid_search_Log = GridSearchCV(estimator = Log_Reg, param_grid = param_grid, cv =10, scoring= 'f1')

# %%
grid_search_Log.fit(X_train,y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# ...

# %%
grid_search_Log.best_params_
# Out:
# {'C': 1,
#  'class_weight': {0: 0.45, 1: 0.55},
#  'max_iter': 1000,
#  'penalty': 'l2',
#  'solver': 'newton-cg'}

# %%
Lrg = grid_search_Log.best_estimator_

# %%
ytrain_predict_Log = Lrg.predict(X_train)
ytest_predict_Log = Lrg.predict(X_test)

# TRAIN

                                            

print('**Classification Report Training Data:**')
print(classification_report(y_train, ytrain_predict_Log))
# Train AUC Score
probs = Lrg.predict_proba(X_train)
ytrain_predict_prob_Log = probs[:, 1]
auc = roc_auc_score(y_train, ytrain_predict_prob_Log)
print('AUC Score Training Data: %.3f' % auc)


# TEST

print('**Classification Report Testing Data:**')
print(classification_report(y_test, ytest_predict_Log))
# AUC Score
probs = Lrg.predict_proba(X_test)
ytest_predict_prob_Log = probs[:, 1]
auc = roc_auc_score(y_test, ytest_predict_prob_Log)
print('AUC Score Testing Data: %.3f' % auc)
# Out:
# **Classification Report Training Data:**
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70       326
#            1       0.65      0.65      0.65       284
#
#     accuracy                           0.68       610
#    macro avg       0.68      0.68      0.68       610
# weighted avg       0.68      0.68      0.68       610
#
# AUC Score Training Data: 0.742
# **Classification Report Testing Data:**
#               precision    recall  f1-score   support
#
#            0       0.72      0.65      0.68       145
#            1       0.61      0.69      0.65       117
#
#     accuracy                           0.67       262
#    macro avg       0.67      0.67      0.67       262
# weighted avg       0.67      0.67      0.67       262
#
# AUC Score Testing Data: 0.705

# %%
from sklearn.metrics import confusion_matrix

# %%
ytrain_predict = Lrg.predict(X_train)
ytest_predict = Lrg.predict(X_test)

# %%
tn, fp, fn, tp = confusion_matrix(y_train, ytrain_predict).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
# Out:
# True Negatives:  227
# False Positives:  99
# False Negatives:  98
# True Positives:  186

# %%
tn, fp, fn, tp = confusion_matrix(y_test, ytest_predict).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
# Out:
# True Negatives:  94
# False Positives:  51
# False Negatives:  36
# True Positives:  81

# %%
confusion_matrix(y_train, ytrain_predict)
sns.heatmap(confusion_matrix(y_train, ytrain_predict),annot=True, fmt='d',cmap='icefire', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
confusion_matrix(y_test, ytest_predict)
sns.heatmap(confusion_matrix(y_train, ytrain_predict),annot=True, fmt='d',cmap='icefire', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
probs = Lrg.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.742

# %%
probs = Lrg.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.705

# %%
# Combination 2 
# penalty l1
# Solver: 'liblinear', 'saga

# %%
param_grid = {
    'solver': ['liblinear', 'saga'],
    'penalty': ['l1'],
    'max_iter': [ 1000, 5000, 10000 ],
    'C': [0.009,0.01]
    }

# %%
grid_search_Log = GridSearchCV(estimator = Log_Reg, param_grid = param_grid, cv = 10, scoring='f1')

# %%
grid_search_Log.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
grid_search_Log.best_params_
# Out:
# {'C': 0.01, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
Lrg1 = grid_search_Log.best_estimator_

# %%
ytrain_predict_Log1 = Lrg1.predict(X_train)
ytest_predict_Log1 = Lrg1.predict(X_test)


# TRAIN

                                            

print('**Classification Report Training Data:**')
print(classification_report(y_train, ytrain_predict_Log1))
# Train AUC Score
probs = Lrg1.predict_proba(X_train)
ytrain_predict_prob_Log1 = probs[:, 1]
auc = roc_auc_score(y_train, ytrain_predict_prob_Log1)
print('AUC Score Training Data: %.3f' % auc)

# TEST

print('**Classification Report Testing Data:**')
print(classification_report(y_test, ytest_predict_Log1))
# AUC Score
probs = Lrg1.predict_proba(X_test)
ytest_predict_prob_Log1 = probs[:, 1]
auc = roc_auc_score(y_test, ytest_predict_prob_Log1)
print('AUC Score Testing Data: %.3f' % auc)
# Out:
# **Classification Report Training Data:**
#               precision    recall  f1-score   support
#
#            0       0.53      0.95      0.68       326
#            1       0.41      0.04      0.07       284
#
#     accuracy                           0.53       610
#    macro avg       0.47      0.49      0.38       610
# weighted avg       0.47      0.53      0.40       610
#
# AUC Score Training Data: 0.572
# **Classification Report Testing Data:**
#               precision    recall  f1-score   support
#
#            0       0.55      0.98      0.70       145
#            1       0.25      0.01      0.02       117
#
#     accuracy                           0.55       262
#    macro avg       0.40      0.49      0.36       262
# weighted avg       0.42      0.55      0.40       262
#
# AUC Score Testing Data: 0.629

# %%
 ytrain_predict1 = Lrg.predict(X_train)
ytest_predict1= Lrg.predict(X_test)

tn, fp, fn, tp = confusion_matrix(y_train, ytrain_predict1).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
# Out:
# True Negatives:  227
# False Positives:  99
# False Negatives:  98
# True Positives:  186

# %%
tn, fp, fn, tp = confusion_matrix(y_test, ytest_predict1).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
# Out:
# True Negatives:  94
# False Positives:  51
# False Negatives:  36
# True Positives:  81

# %%
probs = Lrg1.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.572

# %%
probs = Lrg1.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.629

# %%
#Combination 3
#penalty: 'elasticnet'
#solver: 'saga

# %%
param_grid = {
    'solver': ['saga'],
    'penalty': ['elasticnet'],
    'max_iter': [ 1000, 5000, 10000 ], 
    'tol': [ 0.0001, 0.001],
    'C':[0.001,.009,0.01,.09],
    'l1_ratio': [0.1, 0.3, 0.5, 0.9],
    'class_weight': [{1: 0.5, 0: 0.5},{1:0.55, 0:0.45}]
    }

# %%
grid_search_Log = GridSearchCV(estimator = Log_Reg, param_grid = param_grid, cv = 10, scoring='f1')

# %%
grid_search_Log.fit(X_train,y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
grid_search_Log.best_params_
# Out:
# {'C': 0.001,
#  'class_weight': {0: 0.45, 1: 0.55},
#  'l1_ratio': 0.1,
#  'max_iter': 10000,
#  'penalty': 'elasticnet',
#  'solver': 'saga',
#  'tol': 0.0001}

# %%
Lrg2 = grid_search_Log.best_estimator_

# %%
ytrain_predict_Log2 = Lrg2.predict(X_train)
ytest_predict_Log2= Lrg2.predict(X_test)

# %%
print('**Classification Report Training Data:**')
print(classification_report(y_train, ytrain_predict_Log2))
# Train AUC Score
probs = Lrg2.predict_proba(X_train)
ytrain_predict_prob_Log2 = probs[:, 1]
auc = roc_auc_score(y_train, ytrain_predict_prob_Log2)
print('AUC Score Training Data: %.3f' % auc)

# TEST

print('**Classification Report Testing Data:**')
print(classification_report(y_test, ytest_predict_Log2))
# AUC Score
probs = Lrg2.predict_proba(X_test)
ytest_predict_prob_Log2= probs[:, 1]
auc = roc_auc_score(y_test, ytest_predict_prob_Log2)
print('AUC Score Testing Data: %.3f' % auc)
# Out:
# **Classification Report Training Data:**
#               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70       326
#            1       1.00      0.00      0.01       284
#
#     accuracy                           0.54       610
#    macro avg       0.77      0.50      0.35       610
# weighted avg       0.75      0.54      0.38       610
#
# AUC Score Training Data: 0.590
# **Classification Report Testing Data:**
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71       145
#            1       0.00      0.00      0.00       117
#
#     accuracy                           0.55       262
#    macro avg       0.28      0.50      0.36       262
# weighted avg       0.31      0.55      0.39       262
#
# AUC Score Testing Data: 0.634
# ...

# %%
ytrain_predict2 = Lrg2.predict(X_train)
ytest_predict2 = Lrg2.predict(X_test)

# %%
tn, fp, fn, tp = confusion_matrix(y_train, ytrain_predict2).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
# Out:
# True Negatives:  326
# False Positives:  0
# False Negatives:  283
# True Positives:  1

# %%
probs = Lrg2.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.590

# %%
probs = Lrg2.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.634

# %%
#Combination 4
#penalty: 'none'
#solver: 'newton-cg', 'lbfgs', 'sag', 'saga'

# %%
param_grid = {
    'solver': ['newton-cg', 'lbfgs', 'sag', 'saga'],
    'penalty': ['none'],
    'max_iter': [ 1000, 5000, 10000 ], 
    'tol': [ 0.0001, 0.01, 0.1],
    'class_weight': [{1: 0.5, 0: 0.5},{1:0.55, 0:0.45}]
    }

# %%
grid_search_Log = GridSearchCV(estimator = Log_Reg, param_grid = param_grid, cv = 10, scoring='f1')

# %%
grid_search_Log.fit(X_train,y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# ...

# %%
grid_search_Log.best_params_
# Out:
# {'C': 0.001,
#  'class_weight': {0: 0.45, 1: 0.55},
#  'l1_ratio': 0.1,
#  'max_iter': 10000,
#  'penalty': 'elasticnet',
#  'solver': 'saga',
#  'tol': 0.0001}

# %%
Lrg3 = grid_search_Log.best_estimator_

# %%
ytrain_predict_Log3 = Lrg3.predict(X_train)
ytest_predict_Log3 = Lrg3.predict(X_test)

# %%
print('**Classification Report Training Data:**')
print(classification_report(y_train, ytrain_predict_Log3))
# Train AUC Score
probs = Lrg3.predict_proba(X_train)
ytrain_predict_prob_Log3 = probs[:, 1]
auc = roc_auc_score(y_train, ytrain_predict_prob_Log3)
print('AUC Score Training Data: %.3f' % auc)

# TEST

print('**Classification Report Testing Data:**')
print(classification_report(y_test, ytest_predict_Log3))
# AUC Score
probs = Lrg3.predict_proba(X_test)
ytest_predict_prob_Log3 = probs[:, 1]
auc = roc_auc_score(y_test, ytest_predict_prob_Log3)
print('AUC Score Testing Data: %.3f' % auc)
# Out:
# **Classification Report Training Data:**
#               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70       326
#            1       1.00      0.00      0.01       284
#
#     accuracy                           0.54       610
#    macro avg       0.77      0.50      0.35       610
# weighted avg       0.75      0.54      0.38       610
#
# AUC Score Training Data: 0.590
# **Classification Report Testing Data:**
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71       145
#            1       0.00      0.00      0.00       117
#
#     accuracy                           0.55       262
#    macro avg       0.28      0.50      0.36       262
# weighted avg       0.31      0.55      0.39       262
#
# AUC Score Testing Data: 0.634
# ...

# %%
ytrain_predict3 = Lrg3.predict(X_train)
ytest_predict3 = Lrg3.predict(X_test)

# %%
tn, fp, fn, tp = confusion_matrix(y_train, ytrain_predict3).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
# Out:
# True Negatives:  326
# False Positives:  0
# False Negatives:  283
# True Positives:  1

# %%
confusion_matrix(y_test, ytest_predict3)
sns.heatmap(confusion_matrix(y_train, ytrain_predict3),annot=True, fmt='d',cmap='icefire', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()

# %%
probs = Lrg3.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.590

# %%
probs = Lrg3.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.634
